# %%
from PIL import Image
import numpy as np
import os
from pathlib import Path
import logging
from tqdm import tqdm  # For progress tracking

def preprocess_directory_images(directory_path, output_size=(1024, 1024), resize_method='bicubic'):
    """
    Preprocess all images in a directory by resizing them to the specified dimensions.
    Original images are replaced with the processed versions.
    
    Parameters:
        directory_path (str): Path to the directory containing images
        output_size (tuple): Desired output dimensions (width, height)
        resize_method (str): The resampling filter to use
    """
    # Set up logging to track any errors or issues
    logging.basicConfig(level=logging.INFO)
    logger = logging.getLogger(__name__)
    
    # Create a mapping for different image formats that PIL can handle
    supported_formats = {'.jpg', '.jpeg', '.png', '.bmp', '.tiff'}
    
    # Create filter mapping for resize methods
    filter_map = {
        'nearest': Image.NEAREST,
        'bilinear': Image.BILINEAR,
        'bicubic': Image.BICUBIC,
        'lanczos': Image.LANCZOS
    }
    resample_filter = filter_map.get(resize_method.lower(), Image.BICUBIC)
    
    # Get all image files in the directory
    directory = Path(directory_path)
    image_files = [f for f in directory.glob('*') if f.suffix.lower() in supported_formats]
    
    if not image_files:
        logger.warning(f"No supported image files found in {directory_path}")
        return
    
    # Process each image with a progress bar
    for image_path in tqdm(image_files, desc="Processing images"):
        try:
            # Load the image
            img = Image.open(image_path)
            
            # Convert to RGB if image is in another mode
            if img.mode != 'RGB':
                img = img.convert('RGB')
            
            # Calculate aspect ratio preserving dimensions
            original_width, original_height = img.size
            aspect_ratio = original_width / original_height
            
            if aspect_ratio > 1:
                new_width = output_size[0]
                new_height = int(new_width / aspect_ratio)
            else:
                new_height = output_size[1]
                new_width = int(new_height * aspect_ratio)
            
            # Resize the image while preserving aspect ratio
            img_resized = img.resize((new_width, new_height), resample_filter)
            
            # Create a new black background
            background = Image.new('RGB', output_size, (0, 0, 0))
            
            # Calculate position to paste the resized image
            paste_x = (output_size[0] - new_width) // 2
            paste_y = (output_size[1] - new_height) // 2
            
            # Paste the resized image onto the background
            background.paste(img_resized, (paste_x, paste_y))
            
            # Save the processed image, replacing the original
            # Using high quality for JPEG to minimize compression artifacts
            background.save(image_path, quality=95, optimize=True)
            
            logger.info(f"Successfully processed: {image_path.name}")
            
        except Exception as e:
            logger.error(f"Error processing {image_path.name}: {str(e)}")
            continue

# Example usage:
directory_path = 'images/'
preprocess_directory_images(
    directory_path,
    output_size=(1024, 1024),
    resize_method='bicubic'
)
# Out:
# Processing images:   0%|          | 0/47 [00:00<?, ?it/s]INFO:__main__:Successfully processed: pexels-layg-traveller-593127578-21296391.jpg
# Processing images:   2%|▏         | 1/47 [00:00<00:09,  4.84it/s]INFO:__main__:Successfully processed: pexels-gsn-travel-28386048.jpg
# Processing images:   4%|▍         | 2/47 [00:00<00:12,  3.67it/s]INFO:__main__:Successfully processed: pexels-gsn-travel-28432005.jpg
# Processing images:   6%|▋         | 3/47 [00:00<00:11,  3.96it/s]INFO:__main__:Successfully processed: pexels-mutecevvil-15679626.jpg
# INFO:__main__:Successfully processed: pexels-kelly-1179532-29512751.jpg
# Processing images:  11%|█         | 5/47 [00:01<00:13,  3.02it/s]INFO:__main__:Successfully processed: pexels-ahmetyuksek-21345810.jpg
# Processing images:  13%|█▎        | 6/47 [00:01<00:12,  3.29it/s]INFO:__main__:Successfully processed: pexels-gsn-travel-28432002.jpg
# Processing images:  15%|█▍        | 7/47 [00:02<00:11,  3.38it/s]INFO:__main__:Successfully processed: pexels-kelly-1179532-29693631.jpg
# Processing images:  17%|█▋        | 8/47 [00:02<00:10,  3.65it/s]INFO:__main__:Successfully processed: pexels-layg-traveller-593127578-29539790.jpg
# Processing images:  19%|█▉        | 9/47 [00:02<00:09,  4.01it/s]INFO:__main__:Successfully processed: pexels-kelly-1179532-29740426.jpg
# Processing images:  21%|██▏       | 10/47 [00:02<00:09,  3.92it/s]INFO:__main__:Successfully processed: pexels-davidpickup-28609723.jpg
# Processing images:  23%|██▎       | 11/47 [00:02<00:08,  4.25it/s]INFO:__main__:Successfully processed: pexels-layg-traveller-593127578-26976920.jpg
# Processing images:  26%|██▌       | 12/47 [00:03<00:07,  4.89it/s]INFO:__main__:Successfully processed: pexels-gsn-travel-28359700.jpg
# Processing images:  28%|██▊       | 13/47 [00:03<00:08,  3.99it/s]INFO:__main__:Successfully processed: pexels-gsn-travel-29421050.jpg
# Processing images:  30%|██▉       | 14/47 [00:04<00:12,  2.61it/s]INFO:__main__:Successfully processed: pexels-mutecevvil-15828946.jpg
# Processing images:  32%|███▏      | 15/47 [00:04<00:12,  2.56it/s]INFO:__main__:Successfully processed: pexels-layg-traveller-593127578-21243708.jpg
# Processing images:  34%|███▍      | 16/47 [00:04<00:10,  3.04it/s]INFO:__main__:Successfully processed: pexels-kelly-1179532-29740423.jpg
# Processing images:  36%|███▌      | 17/47 [00:04<00:09,  3.32it/s]INFO:__main__:Successfully processed: pexels-gsn-travel-28489224.jpg
# Processing images:  38%|███▊      | 18/47 [00:05<00:08,  3.46it/s]INFO:__main__:Successfully processed: pexels-mutecevvil-16000872.jpg
# Processing images:  40%|████      | 19/47 [00:05<00:09,  3.04it/s]INFO:__main__:Successfully processed: pexels-layg-traveller-593127578-21243704.jpg
# Processing images:  43%|████▎     | 20/47 [00:05<00:07,  3.59it/s]INFO:__main__:Successfully processed: pexels-kelly-1179532-29070010.jpg
# Processing images:  45%|████▍     | 21/47 [00:06<00:09,  2.82it/s]INFO:__main__:Successfully processed: pexels-ahmetyuksek-29606572.jpg
# Processing images:  47%|████▋     | 22/47 [00:06<00:07,  3.57it/s]INFO:__main__:Successfully processed: pexels-gsn-travel-28359696.jpg
# Processing images:  49%|████▉     | 23/47 [00:06<00:06,  3.46it/s]INFO:__main__:Successfully processed: pexels-ahmetyuksek-29397701.jpg
# Processing images:  51%|█████     | 24/47 [00:06<00:06,  3.67it/s]INFO:__main__:Successfully processed: pexels-kelly-1179532-29740398.jpg
# Processing images:  53%|█████▎    | 25/47 [00:07<00:06,  3.60it/s]INFO:__main__:Successfully processed: pexels-layg-traveller-593127578-21248912.jpg
# Processing images:  55%|█████▌    | 26/47 [00:07<00:04,  4.37it/s]INFO:__main__:Successfully processed: pexels-gsn-travel-28359719.jpg
# Processing images:  57%|█████▋    | 27/47 [00:07<00:04,  4.58it/s]INFO:__main__:Successfully processed: pexels-ahmetyuksek-29644626.jpg
# Processing images:  60%|█████▉    | 28/47 [00:07<00:04,  4.67it/s]INFO:__main__:Successfully processed: pexels-layg-traveller-593127578-21221384.jpg
# Processing images:  62%|██████▏   | 29/47 [00:07<00:03,  5.36it/s]INFO:__main__:Successfully processed: pexels-layg-traveller-593127578-21221385.jpg
# Processing images:  64%|██████▍   | 30/47 [00:08<00:02,  5.94it/s]INFO:__main__:Successfully processed: pexels-gsn-travel-28386068.jpg
# Processing images:  66%|██████▌   | 31/47 [00:08<00:03,  4.76it/s]INFO:__main__:Successfully processed: pexels-mutecevvil-12572038.jpg
# Processing images:  68%|██████▊   | 32/47 [00:08<00:03,  4.49it/s]INFO:__main__:Successfully processed: pexels-kelly-1179532-29512760.jpg
# Processing images:  70%|███████   | 33/47 [00:09<00:04,  3.32it/s]INFO:__main__:Successfully processed: pexels-altaf-shah-3143825-12340778.jpg
# Processing images:  72%|███████▏  | 34/47 [00:09<00:03,  3.81it/s]INFO:__main__:Successfully processed: pexels-gsn-travel-28386055.jpg
# Processing images:  74%|███████▍  | 35/47 [00:09<00:03,  3.43it/s]INFO:__main__:Successfully processed: pexels-gsn-travel-28958104.jpg
# Processing images:  77%|███████▋  | 36/47 [00:09<00:03,  3.34it/s]INFO:__main__:Successfully processed: pexels-ahmetyuksek-28802246.jpg
# Processing images:  79%|███████▊  | 37/47 [00:10<00:03,  2.69it/s]INFO:__main__:Successfully processed: pexels-mutecevvil-15889935.jpg
# Processing images:  81%|████████  | 38/47 [00:10<00:03,  2.64it/s]INFO:__main__:Successfully processed: pexels-layg-traveller-593127578-27809086.jpg
# Processing images:  83%|████████▎ | 39/47 [00:10<00:02,  3.25it/s]INFO:__main__:Successfully processed: pexels-mutecevvil-11276231.jpg
# Processing images:  85%|████████▌ | 40/47 [00:11<00:01,  3.63it/s]INFO:__main__:Successfully processed: pexels-ahmetyuksek-29912747.jpg
# Processing images:  87%|████████▋ | 41/47 [00:11<00:01,  3.36it/s]INFO:__main__:Successfully processed: pexels-gsn-travel-28277493.jpg
# Processing images:  89%|████████▉ | 42/47 [00:11<00:01,  3.21it/s]INFO:__main__:Successfully processed: pexels-ahmetyuksek-29784884.jpg
# Processing images:  91%|█████████▏| 43/47 [00:12<00:01,  2.76it/s]INFO:__main__:Successfully processed: pexels-altaf-shah-3143825-5507505.jpg
# Processing images:  94%|█████████▎| 44/47 [00:12<00:00,  3.45it/s]INFO:__main__:Successfully processed: pexels-ahmetyuksek-29246933.jpg
# Processing images:  96%|█████████▌| 45/47 [00:12<00:00,  3.85it/s]INFO:__main__:Successfully processed: pexels-kelly-1179532-29512771.jpg
# Processing images:  98%|█████████▊| 46/47 [00:13<00:00,  2.82it/s]INFO:__main__:Successfully processed: pexels-gsn-travel-28386078.jpg
# Processing images: 100%|██████████| 47/47 [00:13<00:00,  3.46it/s]
